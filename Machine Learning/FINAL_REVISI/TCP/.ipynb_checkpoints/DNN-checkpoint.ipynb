# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns; sns.set()
from keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score
import joblib
import time
from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
features, labels = [], []
training_files = ["dataset/individual/tcp_dataset_individual_attack_1.csv",
                  "dataset/individual/tcp_dataset_individual_attack_2.csv",
                  "dataset/individual/tcp_dataset_individual_normal_1.csv",
                  "dataset/individual/tcp_dataset_individual_normal_2.csv"]

training_files_old = ["dataset/individual/old/dataset_tcp_attack_1.csv",
                  "dataset/individual/old/dataset_tcp_attack_1.csv",
                  "dataset/individual/old/dataset_tcp_normal_1.csv",
                  "dataset/individual/old/dataset_tcp_normal_2.csv",
                  "dataset/individual/old/dataset_tcp_normal_3.csv"]

# %%
def scrape_data():
    global training_files
    global features
    global labels
    
    for fname in training_files:
        meal = open(fname, "rt")
        for line in meal:
            data_list = line.rsplit(",")
            if(len(data_list) != 14):
                print("error data")
            else:
                data_list[(len(data_list)-1)]=int(data_list[(len(data_list)-1)].replace('\n', ''))
                features.append(data_list[:(len(data_list)-1)])
                labels.append(data_list[(len(data_list)-1)])
        meal.close()
    
    for fname in training_files_old:
        meal = open(fname, "rt")
        for line in meal:
            data_list = line.rsplit(",")
            if(len(data_list) != 15):
                print("error data")
            else:
                data_list.pop(3)
                data_list[(len(data_list)-1)]=int(data_list[(len(data_list)-1)].replace('\n', ''))
                features.append(data_list[:(len(data_list)-1)])
                labels.append(data_list[(len(data_list)-1)])
        meal.close()
    
    data_counter = Counter(labels)
    print(data_counter)
    
    over = SMOTE()
    under = RandomUnderSampler()
    steps = [('o', over), ('u', under)]
    pipeline = Pipeline(steps=steps)
    features, labels = pipeline.fit_resample(features, labels)
    
    data_counter = Counter(labels)
    print(data_counter)
    
    scalar = StandardScaler(copy=True, with_mean=True, with_std=True)
    scalar.fit(features)
    features = scalar.transform(features)
    
    features = np.array(features).astype(np.float64)
    features = features.tolist()
    
    print(f"Size of feature dataset : {len(features)}")
    print(f"Size of feature dataset : {len(labels)}")
    print("Features first and last entries:\n\t", end = "")
    print(features[:1] + features[(len(features)-1):])
    print("Labels first and last entries:\n\t", end = "")
    print(labels[:1] + labels[(len(features)-1):])
    
    features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size = 0.20, stratify=labels, random_state = 0)
    
    return np.asarray(features_train), np.asarray(labels_train), np.asarray(features_test), np.asarray(labels_test)

# %%
def generate_model(shape):
    model = Sequential()

    model.add(Dense(256, input_dim=shape, kernel_initializer='uniform', activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    print(model.summary())

    return model

# %%
data_train, label_train, data_eval, label_eval = scrape_data()
# Out:
# Counter({0: 615, 1: 299})
# Counter({0: 615, 1: 615})
# Size of feature dataset : 1230
# Size of feature dataset : 1230
# Features first and last entries:
# 	[[-2.3915196197871342, -0.598565955997845, -1.1498129463756182, 1.0115511986788064, 1.348174968698899, 0.4417578796936334, 0.0, 0.7330202000430488, 0.757586218779634, -0.1546226124183062, 0.0, 0.5765871288382448, -0.9007722656350029], [-0.037090041864884314, 2.0288605612741684, 1.3368457250013055, -0.6043634503031696, -0.49106630752082814, -0.8755092584695637, 0.0, 1.7351902169410867, 0.3184325031598807, 0.30332919187884594, 0.0, -0.7913557709629924, 1.4348572227928085]]
# Labels first and last entries:
# 	[0, 1]
# C:\Users\H P VICTUS\anaconda3\lib\site-packages\sklearn\utils\validation.py:964: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(

# %%
model = generate_model(len(data_train[0]))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               3584
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,849
# Trainable params: 46,849
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               3584
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,849
# Trainable params: 46,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("dnnModel.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=30, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(data_train, label_train, validation_split=0.2, epochs=100, verbose = 1, callbacks=[checkpoint,early])
# Out:
# Epoch 1/100
# 18/25 [====================>.........] - ETA: 0s - loss: 0.5771 - accuracy: 0.8299
# Epoch 00001: val_loss improved from inf to 0.12930, saving model to dnnModel.h5
# 25/25 [==============================] - 1s 9ms/step - loss: 0.5082 - accuracy: 0.8666 - val_loss: 0.1293 - val_accuracy: 1.0000
# Epoch 2/100
# 18/25 [====================>.........] - ETA: 0s - loss: 0.0920 - accuracy: 0.9913
# Epoch 00002: val_loss improved from 0.12930 to 0.00322, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9911 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 3/100
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0112 - accuracy: 0.9985
# Epoch 00003: val_loss improved from 0.00322 to 0.00032, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 3.2055e-04 - val_accuracy: 1.0000
# Epoch 4/100
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0115 - accuracy: 0.9970
# Epoch 00004: val_loss improved from 0.00032 to 0.00006, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 5.7638e-05 - val_accuracy: 1.0000
# Epoch 5/100
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0025 - accuracy: 0.9985
# Epoch 00005: val_loss improved from 0.00006 to 0.00004, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 3.6330e-05 - val_accuracy: 1.0000
# Epoch 6/100
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0054 - accuracy: 0.9985
# Epoch 00006: val_loss improved from 0.00004 to 0.00002, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 1.9370e-05 - val_accuracy: 1.0000
# Epoch 7/100
# 19/25 [=====================>........] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00007: val_loss improved from 0.00002 to 0.00001, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2953e-05 - val_accuracy: 1.0000
# Epoch 8/100
# 19/25 [=====================>........] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00008: val_loss improved from 0.00001 to 0.00001, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.1732e-06 - val_accuracy: 1.0000
# Epoch 9/100
# 21/25 [========================>.....] - ETA: 0s - loss: 6.1485e-04 - accuracy: 1.0000
# Epoch 00009: val_loss improved from 0.00001 to 0.00001, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 5.5754e-04 - accuracy: 1.0000 - val_loss: 5.2800e-06 - val_accuracy: 1.0000
# Epoch 10/100
# 17/25 [===================>..........] - ETA: 0s - loss: 9.1923e-04 - accuracy: 1.0000
# Epoch 00010: val_loss improved from 0.00001 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.1824e-06 - val_accuracy: 1.0000
# Epoch 11/100
# 21/25 [========================>.....] - ETA: 0s - loss: 3.5121e-04 - accuracy: 1.0000
# Epoch 00011: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.8021e-04 - accuracy: 1.0000 - val_loss: 3.5554e-06 - val_accuracy: 1.0000
# Epoch 12/100
# 21/25 [========================>.....] - ETA: 0s - loss: 5.5686e-04 - accuracy: 1.0000
# Epoch 00012: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 4.7771e-04 - accuracy: 1.0000 - val_loss: 2.6335e-06 - val_accuracy: 1.0000
# Epoch 13/100
# 20/25 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00013: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.0314e-06 - val_accuracy: 1.0000
# Epoch 14/100
# 19/25 [=====================>........] - ETA: 0s - loss: 5.9784e-04 - accuracy: 1.0000
# Epoch 00014: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 5.1849e-04 - accuracy: 1.0000 - val_loss: 1.4316e-06 - val_accuracy: 1.0000
# Epoch 15/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.9017e-04 - accuracy: 1.0000
# Epoch 00015: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.5875e-04 - accuracy: 1.0000 - val_loss: 1.1595e-06 - val_accuracy: 1.0000
# Epoch 16/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.1778e-04 - accuracy: 1.0000
# Epoch 00016: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.4022e-04 - accuracy: 1.0000 - val_loss: 9.9434e-07 - val_accuracy: 1.0000
# Epoch 17/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.7429e-04 - accuracy: 1.0000
# Epoch 00017: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.7274e-04 - accuracy: 1.0000 - val_loss: 8.3445e-07 - val_accuracy: 1.0000
# Epoch 18/100
# 19/25 [=====================>........] - ETA: 0s - loss: 7.6297e-05 - accuracy: 1.0000
# Epoch 00018: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 8.2061e-05 - accuracy: 1.0000 - val_loss: 7.8051e-07 - val_accuracy: 1.0000
# Epoch 19/100
# 19/25 [=====================>........] - ETA: 0s - loss: 8.5917e-05 - accuracy: 1.0000
# Epoch 00019: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 9.7945e-05 - accuracy: 1.0000 - val_loss: 7.1465e-07 - val_accuracy: 1.0000
# Epoch 20/100
# 18/25 [====================>.........] - ETA: 0s - loss: 5.3541e-04 - accuracy: 1.0000
# Epoch 00020: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 4.2497e-04 - accuracy: 1.0000 - val_loss: 5.3672e-07 - val_accuracy: 1.0000
# Epoch 21/100
# 17/25 [===================>..........] - ETA: 0s - loss: 2.3782e-04 - accuracy: 1.0000
# Epoch 00021: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 1.6724e-04 - accuracy: 1.0000 - val_loss: 4.5633e-07 - val_accuracy: 1.0000
# Epoch 22/100
# 18/25 [====================>.........] - ETA: 0s - loss: 3.8491e-05 - accuracy: 1.0000
# Epoch 00022: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.5993e-05 - accuracy: 1.0000 - val_loss: 4.2427e-07 - val_accuracy: 1.0000
# Epoch 23/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.6666e-04 - accuracy: 1.0000
# Epoch 00023: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.1097e-04 - accuracy: 1.0000 - val_loss: 2.2057e-07 - val_accuracy: 1.0000
# Epoch 24/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.3502e-04 - accuracy: 1.0000
# Epoch 00024: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2801e-04 - accuracy: 1.0000 - val_loss: 1.7944e-07 - val_accuracy: 1.0000
# Epoch 25/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.2858e-04 - accuracy: 1.0000
# Epoch 00025: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3228e-04 - accuracy: 1.0000 - val_loss: 1.5459e-07 - val_accuracy: 1.0000
# Epoch 26/100
# 17/25 [===================>..........] - ETA: 0s - loss: 5.2759e-04 - accuracy: 1.0000
# Epoch 00026: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 3.7625e-04 - accuracy: 1.0000 - val_loss: 1.0969e-07 - val_accuracy: 1.0000
# Epoch 27/100
# 18/25 [====================>.........] - ETA: 0s - loss: 3.4722e-05 - accuracy: 1.0000
# Epoch 00027: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.6181e-05 - accuracy: 1.0000 - val_loss: 9.7017e-08 - val_accuracy: 1.0000
# Epoch 28/100
# 21/25 [========================>.....] - ETA: 0s - loss: 4.0685e-05 - accuracy: 1.0000
# Epoch 00028: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 4.7073e-05 - accuracy: 1.0000 - val_loss: 8.8986e-08 - val_accuracy: 1.0000
# Epoch 29/100
# 17/25 [===================>..........] - ETA: 0s - loss: 4.6931e-05 - accuracy: 1.0000
# Epoch 00029: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 5.5683e-05 - accuracy: 1.0000 - val_loss: 8.1795e-08 - val_accuracy: 1.0000
# Epoch 30/100
# 19/25 [=====================>........] - ETA: 0s - loss: 4.6938e-05 - accuracy: 1.0000
# Epoch 00030: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.8817e-05 - accuracy: 1.0000 - val_loss: 7.5039e-08 - val_accuracy: 1.0000
# Epoch 31/100
# 18/25 [====================>.........] - ETA: 0s - loss: 3.3696e-05 - accuracy: 1.0000
# Epoch 00031: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 2.6685e-05 - accuracy: 1.0000 - val_loss: 7.1055e-08 - val_accuracy: 1.0000
# Epoch 32/100
# 20/25 [=======================>......] - ETA: 0s - loss: 6.4678e-05 - accuracy: 1.0000
# Epoch 00032: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 5.4573e-05 - accuracy: 1.0000 - val_loss: 6.1167e-08 - val_accuracy: 1.0000
# Epoch 33/100
# 21/25 [========================>.....] - ETA: 0s - loss: 1.5692e-04 - accuracy: 1.0000
# Epoch 00033: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3440e-04 - accuracy: 1.0000 - val_loss: 6.8492e-08 - val_accuracy: 1.0000
# Epoch 34/100
# 21/25 [========================>.....] - ETA: 0s - loss: 4.4486e-04 - accuracy: 1.0000
# Epoch 00034: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 3.8700e-04 - accuracy: 1.0000 - val_loss: 6.5271e-08 - val_accuracy: 1.0000
# Epoch 35/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.3913e-04 - accuracy: 1.0000
# Epoch 00035: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 9.9686e-05 - accuracy: 1.0000 - val_loss: 5.2242e-08 - val_accuracy: 1.0000
# Epoch 36/100
# 18/25 [====================>.........] - ETA: 0s - loss: 3.6836e-05 - accuracy: 1.0000
# Epoch 00036: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.5986e-04 - accuracy: 1.0000 - val_loss: 4.8159e-08 - val_accuracy: 1.0000
# Epoch 37/100
# 19/25 [=====================>........] - ETA: 0s - loss: 3.4225e-05 - accuracy: 1.0000
# Epoch 00037: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 4.6571e-05 - accuracy: 1.0000 - val_loss: 4.9188e-08 - val_accuracy: 1.0000
# Epoch 38/100
# 20/25 [=======================>......] - ETA: 0s - loss: 7.0267e-06 - accuracy: 1.0000
# Epoch 00038: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.0859e-05 - accuracy: 1.0000 - val_loss: 4.7247e-08 - val_accuracy: 1.0000
# Epoch 39/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.7242e-05 - accuracy: 1.0000
# Epoch 00039: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.4473e-05 - accuracy: 1.0000 - val_loss: 4.6566e-08 - val_accuracy: 1.0000
# Epoch 40/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.4988e-05 - accuracy: 1.0000
# Epoch 00040: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 2.4866e-05 - accuracy: 1.0000 - val_loss: 4.3290e-08 - val_accuracy: 1.0000
# Epoch 41/100
# 20/25 [=======================>......] - ETA: 0s - loss: 7.2209e-05 - accuracy: 1.0000
# Epoch 00041: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 6.0445e-05 - accuracy: 1.0000 - val_loss: 3.9326e-08 - val_accuracy: 1.0000
# Epoch 42/100
# 22/25 [=========================>....] - ETA: 0s - loss: 9.6523e-05 - accuracy: 1.0000
# Epoch 00042: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 8.9842e-05 - accuracy: 1.0000 - val_loss: 3.7547e-08 - val_accuracy: 1.0000
# Epoch 43/100
# 19/25 [=====================>........] - ETA: 0s - loss: 9.4643e-06 - accuracy: 1.0000
# Epoch 00043: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 8.8339e-06 - accuracy: 1.0000 - val_loss: 3.6223e-08 - val_accuracy: 1.0000
# Epoch 44/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.8630e-05 - accuracy: 1.0000
# Epoch 00044: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.5339e-05 - accuracy: 1.0000 - val_loss: 3.3508e-08 - val_accuracy: 1.0000
# Epoch 45/100
# 18/25 [====================>.........] - ETA: 0s - loss: 0.0019 - accuracy: 0.9983
# Epoch 00045: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 0.9987 - val_loss: 1.6291e-07 - val_accuracy: 1.0000
# Epoch 46/100
# 21/25 [========================>.....] - ETA: 0s - loss: 9.5793e-05 - accuracy: 1.0000
# Epoch 00046: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3218e-04 - accuracy: 1.0000 - val_loss: 5.5898e-08 - val_accuracy: 1.0000
# Epoch 47/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.8514e-05 - accuracy: 1.0000
# Epoch 00047: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.0144e-05 - accuracy: 1.0000 - val_loss: 2.7578e-08 - val_accuracy: 1.0000
# Epoch 48/100
# 22/25 [=========================>....] - ETA: 0s - loss: 4.5363e-05 - accuracy: 1.0000
# Epoch 00048: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 4.4166e-05 - accuracy: 1.0000 - val_loss: 2.3218e-08 - val_accuracy: 1.0000
# Epoch 49/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.2973e-04 - accuracy: 1.0000
# Epoch 00049: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.0136e-04 - accuracy: 1.0000 - val_loss: 1.4346e-08 - val_accuracy: 1.0000
# Epoch 50/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.2694e-05 - accuracy: 1.0000
# Epoch 00050: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.0359e-05 - accuracy: 1.0000 - val_loss: 1.2196e-08 - val_accuracy: 1.0000
# Epoch 51/100
# 19/25 [=====================>........] - ETA: 0s - loss: 3.7900e-05 - accuracy: 1.0000
# Epoch 00051: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.9434e-05 - accuracy: 1.0000 - val_loss: 1.0900e-08 - val_accuracy: 1.0000
# Epoch 52/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.1043e-04 - accuracy: 1.0000
# Epoch 00052: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 9.0270e-05 - accuracy: 1.0000 - val_loss: 8.2820e-09 - val_accuracy: 1.0000
# Epoch 53/100
# 18/25 [====================>.........] - ETA: 0s - loss: 2.9183e-05 - accuracy: 1.0000
# Epoch 00053: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.1579e-05 - accuracy: 1.0000 - val_loss: 7.3255e-09 - val_accuracy: 1.0000
# Epoch 54/100
# 20/25 [=======================>......] - ETA: 0s - loss: 9.1973e-07 - accuracy: 1.0000
# Epoch 00054: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.3048e-05 - accuracy: 1.0000 - val_loss: 6.8682e-09 - val_accuracy: 1.0000
# Epoch 55/100
# 19/25 [=====================>........] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00055: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 8.9360e-04 - accuracy: 1.0000 - val_loss: 6.2816e-09 - val_accuracy: 1.0000
# Epoch 56/100
# 17/25 [===================>..........] - ETA: 0s - loss: 7.1763e-07 - accuracy: 1.0000
# Epoch 00056: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.4318e-05 - accuracy: 1.0000 - val_loss: 6.0783e-09 - val_accuracy: 1.0000
# Epoch 57/100
# 21/25 [========================>.....] - ETA: 0s - loss: 9.2258e-05 - accuracy: 1.0000
# Epoch 00057: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 7.9591e-05 - accuracy: 1.0000 - val_loss: 5.5859e-09 - val_accuracy: 1.0000
# Epoch 58/100
# 20/25 [=======================>......] - ETA: 0s - loss: 5.3768e-06 - accuracy: 1.0000
# Epoch 00058: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 9.0297e-06 - accuracy: 1.0000 - val_loss: 5.0907e-09 - val_accuracy: 1.0000
# Epoch 59/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.0014e-05 - accuracy: 1.0000
# Epoch 00059: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7529e-05 - accuracy: 1.0000 - val_loss: 4.8271e-09 - val_accuracy: 1.0000
# Epoch 60/100
# 20/25 [=======================>......] - ETA: 0s - loss: 3.9131e-05 - accuracy: 1.0000
# Epoch 00060: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.2223e-05 - accuracy: 1.0000 - val_loss: 4.5408e-09 - val_accuracy: 1.0000
# Epoch 61/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.4840e-06 - accuracy: 1.0000
# Epoch 00061: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.9982e-06 - accuracy: 1.0000 - val_loss: 4.4671e-09 - val_accuracy: 1.0000
# Epoch 62/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.2909e-05 - accuracy: 1.0000
# Epoch 00062: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.7535e-05 - accuracy: 1.0000 - val_loss: 4.2833e-09 - val_accuracy: 1.0000
# Epoch 63/100
# 19/25 [=====================>........] - ETA: 0s - loss: 7.8351e-06 - accuracy: 1.0000
# Epoch 00063: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 6.5033e-06 - accuracy: 1.0000 - val_loss: 3.9242e-09 - val_accuracy: 1.0000
# Epoch 64/100
# 21/25 [========================>.....] - ETA: 0s - loss: 3.9342e-04 - accuracy: 1.0000
# Epoch 00064: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.3816e-04 - accuracy: 1.0000 - val_loss: 3.5749e-09 - val_accuracy: 1.0000
# Epoch 65/100
# 21/25 [========================>.....] - ETA: 0s - loss: 5.1611e-06 - accuracy: 1.0000
# Epoch 00065: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 4.5694e-06 - accuracy: 1.0000 - val_loss: 3.4424e-09 - val_accuracy: 1.0000
# Epoch 66/100
# 19/25 [=====================>........] - ETA: 0s - loss: 5.9607e-06 - accuracy: 1.0000
# Epoch 00066: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2432e-05 - accuracy: 1.0000 - val_loss: 3.2814e-09 - val_accuracy: 1.0000
# Epoch 67/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.0321e-05 - accuracy: 1.0000
# Epoch 00067: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.9012e-05 - accuracy: 1.0000 - val_loss: 3.1300e-09 - val_accuracy: 1.0000
# Epoch 68/100
# 18/25 [====================>.........] - ETA: 0s - loss: 2.5187e-05 - accuracy: 1.0000
# Epoch 00068: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.0083e-05 - accuracy: 1.0000 - val_loss: 2.9448e-09 - val_accuracy: 1.0000
# Epoch 69/100
# 21/25 [========================>.....] - ETA: 0s - loss: 9.6822e-06 - accuracy: 1.0000
# Epoch 00069: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0131e-05 - accuracy: 1.0000 - val_loss: 2.8607e-09 - val_accuracy: 1.0000
# Epoch 70/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.5511e-05 - accuracy: 1.0000
# Epoch 00070: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.0318e-04 - accuracy: 1.0000 - val_loss: 2.7019e-09 - val_accuracy: 1.0000
# Epoch 71/100
# 20/25 [=======================>......] - ETA: 0s - loss: 5.7380e-05 - accuracy: 1.0000
# Epoch 00071: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 6.2839e-05 - accuracy: 1.0000 - val_loss: 1.9618e-09 - val_accuracy: 1.0000
# Epoch 72/100
# 20/25 [=======================>......] - ETA: 0s - loss: 4.4445e-06 - accuracy: 1.0000
# Epoch 00072: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 7.2153e-06 - accuracy: 1.0000 - val_loss: 1.7121e-09 - val_accuracy: 1.0000
# Epoch 73/100
# 19/25 [=====================>........] - ETA: 0s - loss: 8.8662e-05 - accuracy: 1.0000
# Epoch 00073: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 6.8795e-05 - accuracy: 1.0000 - val_loss: 7.4456e-10 - val_accuracy: 1.0000
# Epoch 74/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.5035e-05 - accuracy: 1.0000
# Epoch 00074: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.9386e-05 - accuracy: 1.0000 - val_loss: 4.9814e-10 - val_accuracy: 1.0000
# Epoch 75/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.7789e-06 - accuracy: 1.0000
# Epoch 00075: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.7728e-06 - accuracy: 1.0000 - val_loss: 4.7242e-10 - val_accuracy: 1.0000
# Epoch 76/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.5252e-05 - accuracy: 1.0000
# Epoch 00076: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 1.1232e-05 - accuracy: 1.0000 - val_loss: 4.5796e-10 - val_accuracy: 1.0000
# Epoch 77/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.8712e-06 - accuracy: 1.0000
# Epoch 00077: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.3414e-06 - accuracy: 1.0000 - val_loss: 4.4756e-10 - val_accuracy: 1.0000
# Epoch 78/100
# 19/25 [=====================>........] - ETA: 0s - loss: 9.9016e-06 - accuracy: 1.0000
# Epoch 00078: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 4.6541e-05 - accuracy: 1.0000 - val_loss: 4.2843e-10 - val_accuracy: 1.0000
# Epoch 79/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.6386e-05 - accuracy: 1.0000
# Epoch 00079: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.2031e-05 - accuracy: 1.0000 - val_loss: 3.2679e-10 - val_accuracy: 1.0000
# Epoch 80/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.0210e-06 - accuracy: 1.0000
# Epoch 00080: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.5289e-05 - accuracy: 1.0000 - val_loss: 3.0860e-10 - val_accuracy: 1.0000
# Epoch 81/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.0605e-05 - accuracy: 1.0000
# Epoch 00081: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 2.7460e-04 - accuracy: 1.0000 - val_loss: 2.6578e-10 - val_accuracy: 1.0000
# Epoch 82/100
# 16/25 [==================>...........] - ETA: 0s - loss: 3.9181e-05 - accuracy: 1.0000
# Epoch 00082: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 3.6467e-05 - accuracy: 1.0000 - val_loss: 2.4280e-10 - val_accuracy: 1.0000
# Epoch 83/100
# 16/25 [==================>...........] - ETA: 0s - loss: 9.5713e-06 - accuracy: 1.0000
# Epoch 00083: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 6.9236e-06 - accuracy: 1.0000 - val_loss: 2.3603e-10 - val_accuracy: 1.0000
# Epoch 84/100
# 15/25 [=================>............] - ETA: 0s - loss: 1.2073e-05 - accuracy: 1.0000
# Epoch 00084: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 1.2317e-05 - accuracy: 1.0000 - val_loss: 2.3289e-10 - val_accuracy: 1.0000
# Epoch 85/100
# 18/25 [====================>.........] - ETA: 0s - loss: 2.3444e-04 - accuracy: 1.0000
# Epoch 00085: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7296e-04 - accuracy: 1.0000 - val_loss: 4.5174e-08 - val_accuracy: 1.0000
# Epoch 86/100
# 17/25 [===================>..........] - ETA: 0s - loss: 8.8853e-06 - accuracy: 1.0000
# Epoch 00086: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 5.1946e-05 - accuracy: 1.0000 - val_loss: 3.4673e-06 - val_accuracy: 1.0000
# Epoch 87/100
# 17/25 [===================>..........] - ETA: 0s - loss: 9.1505e-06 - accuracy: 1.0000
# Epoch 00087: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 9.4053e-06 - accuracy: 1.0000 - val_loss: 4.9555e-07 - val_accuracy: 1.0000
# Epoch 88/100
# 15/25 [=================>............] - ETA: 0s - loss: 1.6894e-06 - accuracy: 1.0000
# Epoch 00088: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 3.3937e-05 - accuracy: 1.0000 - val_loss: 2.8319e-07 - val_accuracy: 1.0000
# Epoch 89/100
# 17/25 [===================>..........] - ETA: 0s - loss: 2.4759e-04 - accuracy: 1.0000
# Epoch 00089: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 6ms/step - loss: 1.7295e-04 - accuracy: 1.0000 - val_loss: 1.2141e-10 - val_accuracy: 1.0000
# Epoch 90/100
# 14/25 [===============>..............] - ETA: 0s - loss: 1.5281e-06 - accuracy: 1.0000
# Epoch 00090: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 1.1782e-07 - val_accuracy: 1.0000
# Epoch 91/100
# 19/25 [=====================>........] - ETA: 0s - loss: 0.0056 - accuracy: 0.9984
# Epoch 00091: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 3.1159e-09 - val_accuracy: 1.0000
# Epoch 92/100
# 19/25 [=====================>........] - ETA: 0s - loss: 6.6862e-04 - accuracy: 1.0000
# Epoch 00092: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 5.1737e-04 - accuracy: 1.0000 - val_loss: 7.8746e-11 - val_accuracy: 1.0000
# Epoch 93/100
# 18/25 [====================>.........] - ETA: 0s - loss: 3.6732e-05 - accuracy: 1.0000
# Epoch 00093: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 5.6302e-05 - accuracy: 1.0000 - val_loss: 8.3081e-11 - val_accuracy: 1.0000
# Epoch 94/100
# 19/25 [=====================>........] - ETA: 0s - loss: 4.3053e-05 - accuracy: 1.0000
# Epoch 00094: val_loss improved from 0.00000 to 0.00000, saving model to dnnModel.h5
# 25/25 [==============================] - 0s 5ms/step - loss: 3.3315e-05 - accuracy: 1.0000 - val_loss: 6.8686e-11 - val_accuracy: 1.0000
# Epoch 95/100
# 18/25 [====================>.........] - ETA: 0s - loss: 0.0194 - accuracy: 0.9983
# Epoch 00095: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9987 - val_loss: 1.5176e-07 - val_accuracy: 1.0000
# Epoch 96/100
# 17/25 [===================>..........] - ETA: 0s - loss: 7.5628e-05 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3121e-04 - accuracy: 1.0000 - val_loss: 7.5638e-08 - val_accuracy: 1.0000
# Epoch 97/100
# 18/25 [====================>.........] - ETA: 0s - loss: 7.4686e-05 - accuracy: 1.0000
# Epoch 00097: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.1720e-04 - accuracy: 1.0000 - val_loss: 3.0825e-08 - val_accuracy: 1.0000
# Epoch 98/100
# 19/25 [=====================>........] - ETA: 0s - loss: 5.2875e-06 - accuracy: 1.0000
# Epoch 00098: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 1.4941e-04 - accuracy: 1.0000 - val_loss: 1.0827e-08 - val_accuracy: 1.0000
# Epoch 99/100
# 16/25 [==================>...........] - ETA: 0s - loss: 1.1739e-05 - accuracy: 1.0000
# Epoch 00099: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 7.6895e-06 - accuracy: 1.0000 - val_loss: 4.0177e-09 - val_accuracy: 1.0000
# Epoch 100/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.3401e-05 - accuracy: 1.0000
# Epoch 00100: val_loss did not improve from 0.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4291e-05 - accuracy: 1.0000 - val_loss: 3.3432e-09 - val_accuracy: 1.0000

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('BRNN Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
# plt.savefig('BRNN 200 Model Accuracy.png')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('BRNN Model  Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
# plt.savefig('BRNN 200 Model Loss.png')
plt.show()

# %%
predict = model.predict(data_eval, verbose=1)
# Out:
# 8/8 [==============================] - 0s 1ms/step

# %%
tp = 0
tn = 0
fp = 0
fn = 0
predictn = predict.flatten().round()
predictn = predictn.tolist()
Y_testn = label_eval.tolist()
for i in range(len(Y_testn)):
  if predictn[i]==1 and Y_testn[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_testn[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_testn[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_testn[i]==0:
    fn+=1
to_heat_map =[[tn,fp],[fn,tp]]
to_heat_map = pd.DataFrame(to_heat_map, index = ["Attack","Normal"],columns = ["Attack","Normal"])
ax = sns.heatmap(to_heat_map,annot=True, fmt="d")

# %%
scores = model.evaluate(data_eval, label_eval)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0286e-09 - accuracy: 1.0000
# accuracy: 100.00%

# %%
print(classification_report(Y_testn,predictn))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       123
#            1       1.00      1.00      1.00       123
#
#     accuracy                           1.00       246
#    macro avg       1.00      1.00      1.00       246
# weighted avg       1.00      1.00      1.00       246

# %%
lr_auc = roc_auc_score(Y_testn, predictn)
print('SVM: ROC AUC=%.3f' % (lr_auc))
# Out:
# SVM: ROC AUC=1.000

# %%
time_start = time.perf_counter()
predict = model.predict(data_eval[:1], verbose=1)
print(f"Time elapse for prediction : {time.perf_counter() - time_start}")
print(predict)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# Time elapse for prediction : 0.030304799999999688
# [[3.2838098e-20]]

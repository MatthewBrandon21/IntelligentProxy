# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns; sns.set()
from keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score
import joblib
import time
from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
features, labels = [], []
training_files = ["dataset/individual/icmp_dataset_individual_attack_1.csv",
                  "dataset/individual/icmp_dataset_individual_attack_2.csv",
                  "dataset/individual/icmp_dataset_individual_normal_1.csv",
                  "dataset/individual/icmp_dataset_individual_normal_2.csv"]
training_files_old = ["dataset/individual/old/dataset_icmp_attack.csv",
                  "dataset/individual/old/dataset_icmp_normal.csv"]

# %%
def scrape_data():
    global training_files
    global features
    global labels
    
    for fname in training_files:
        meal = open(fname, "rt")
        for line in meal:
            data_list = line.rsplit(",")
            if(len(data_list) != 8):
                print("error data")
            else:
                data_list[(len(data_list)-1)]=int(data_list[(len(data_list)-1)].replace('\n', ''))
                features.append(data_list[:(len(data_list)-1)])
                labels.append(data_list[(len(data_list)-1)])
        meal.close()
    
    for fname in training_files_old:
        meal = open(fname, "rt")
        for line in meal:
            data_list = line.rsplit(",")
            if(len(data_list) != 8):
                print("error data")
            else:
                data_list[(len(data_list)-1)]=int(data_list[(len(data_list)-1)].replace('\n', ''))
                features.append(data_list[:(len(data_list)-1)])
                labels.append(data_list[(len(data_list)-1)])
        meal.close()
    
    data_counter = Counter(labels)
    print(data_counter)
    
    over = SMOTE()
    under = RandomUnderSampler()
    steps = [('o', over), ('u', under)]
    pipeline = Pipeline(steps=steps)
    features, labels = pipeline.fit_resample(features, labels)
    
    data_counter = Counter(labels)
    print(data_counter)
    
    scalar = StandardScaler(copy=True, with_mean=True, with_std=True)
    scalar.fit(features)
    features = scalar.transform(features)
    
    features = np.array(features).astype(np.float64)
    features = features.tolist()
    
    print(f"Size of feature dataset : {len(features)}")
    print(f"Size of feature dataset : {len(labels)}")
    print("Features first and last entries:\n\t", end = "")
    print(features[:1] + features[(len(features)-1):])
    print("Labels first and last entries:\n\t", end = "")
    print(labels[:1] + labels[(len(features)-1):])
    
    features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size = 0.20, stratify=labels, random_state = 0)
    
    return np.asarray(features_train), np.asarray(labels_train), np.asarray(features_test), np.asarray(labels_test)

# %%
def generate_model(shape):
    model = Sequential()

    model.add(Dense(256, input_dim=shape, kernel_initializer='uniform', activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    print(model.summary())

    return model

# %%
data_train, label_train, data_eval, label_eval = scrape_data()
# Out:
# Counter({0: 733, 1: 521})
# Counter({0: 733, 1: 733})
# Size of feature dataset : 1466
# Size of feature dataset : 1466
# Features first and last entries:
# 	[[-4.326204670697206, -0.6312560290432209, -2.0069661716666443, -0.7436193679930443, -1.0324084043574244, -0.32938887802098615, -0.5128459090245092], [0.10637393957398739, 1.6466160154600342, 0.5309501691792299, -0.7436193679930443, 1.0408373684498449, -0.32938887802098615, 2.2572130484780177]]
# Labels first and last entries:
# 	[0, 1]
# C:\Users\H P VICTUS\anaconda3\lib\site-packages\sklearn\utils\validation.py:964: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(

# %%
model = generate_model(len(data_train[0]))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2048
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45,313
# Trainable params: 45,313
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2048
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45,313
# Trainable params: 45,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("dnnModel.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=30, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(data_train, label_train, validation_split=0.2, epochs=100, verbose = 1, callbacks=[checkpoint,early])
# Out:
# Epoch 1/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.6347 - accuracy: 0.7431
# Epoch 00001: val_loss improved from inf to 0.24937, saving model to dnnModel.h5
# 30/30 [==============================] - 1s 7ms/step - loss: 0.5666 - accuracy: 0.8026 - val_loss: 0.2494 - val_accuracy: 0.9787
# Epoch 2/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.1318 - accuracy: 0.9913
# Epoch 00002: val_loss improved from 0.24937 to 0.04353, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.9883 - val_loss: 0.0435 - val_accuracy: 0.9872
# Epoch 3/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0499 - accuracy: 0.9901
# Epoch 00003: val_loss improved from 0.04353 to 0.04092, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0462 - accuracy: 0.9904 - val_loss: 0.0409 - val_accuracy: 0.9872
# Epoch 4/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0454 - accuracy: 0.9859
# Epoch 00004: val_loss improved from 0.04092 to 0.03499, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 0.9904 - val_loss: 0.0350 - val_accuracy: 0.9872
# Epoch 5/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0625 - accuracy: 0.9908
# Epoch 00005: val_loss improved from 0.03499 to 0.02738, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9936 - val_loss: 0.0274 - val_accuracy: 0.9915
# Epoch 6/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0208 - accuracy: 0.9959
# Epoch 00006: val_loss did not improve from 0.02738
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9947 - val_loss: 0.0329 - val_accuracy: 0.9915
# Epoch 7/100
# 21/30 [====================>.........] - ETA: 0s - loss: 0.0262 - accuracy: 0.9940
# Epoch 00007: val_loss did not improve from 0.02738
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9936 - val_loss: 0.0311 - val_accuracy: 0.9915
# Epoch 8/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0167 - accuracy: 0.9951
# Epoch 00008: val_loss did not improve from 0.02738
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.0413 - val_accuracy: 0.9872
# Epoch 9/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0203 - accuracy: 0.9951
# Epoch 00009: val_loss did not improve from 0.02738
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9947 - val_loss: 0.0335 - val_accuracy: 0.9915
# Epoch 10/100
# 21/30 [====================>.........] - ETA: 0s - loss: 0.0332 - accuracy: 0.9926
# Epoch 00010: val_loss improved from 0.02738 to 0.01363, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 0.9936 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 11/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0277 - accuracy: 0.9918
# Epoch 00011: val_loss improved from 0.01363 to 0.01344, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 0.9936 - val_loss: 0.0134 - val_accuracy: 0.9957
# Epoch 12/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0262 - accuracy: 0.9948
# Epoch 00012: val_loss did not improve from 0.01344
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 0.9947 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 13/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0258 - accuracy: 0.9951
# Epoch 00013: val_loss improved from 0.01344 to 0.01340, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 0.9947 - val_loss: 0.0134 - val_accuracy: 0.9957
# Epoch 14/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0250 - accuracy: 0.9922
# Epoch 00014: val_loss did not improve from 0.01340
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9947 - val_loss: 0.0142 - val_accuracy: 0.9957
# Epoch 15/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0162 - accuracy: 0.9969
# Epoch 00015: val_loss improved from 0.01340 to 0.01263, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9947 - val_loss: 0.0126 - val_accuracy: 0.9957
# Epoch 16/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0255 - accuracy: 0.9948
# Epoch 00016: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 0.9947 - val_loss: 0.0129 - val_accuracy: 0.9957
# Epoch 17/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0183 - accuracy: 0.9951
# Epoch 00017: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.0131 - val_accuracy: 0.9957
# Epoch 18/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0262 - accuracy: 0.9922
# Epoch 00018: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9947 - val_loss: 0.0137 - val_accuracy: 0.9957
# Epoch 19/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0236 - accuracy: 0.9934
# Epoch 00019: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0140 - val_accuracy: 0.9957
# Epoch 20/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0178 - accuracy: 0.9948
# Epoch 00020: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.0170 - val_accuracy: 0.9915
# Epoch 21/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9925
# Epoch 00021: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.0137 - val_accuracy: 0.9957
# Epoch 22/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0319 - accuracy: 0.9902
# Epoch 00022: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9936 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 23/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0234 - accuracy: 0.9951
# Epoch 00023: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9947 - val_loss: 0.0130 - val_accuracy: 0.9957
# Epoch 24/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0116 - accuracy: 0.9963
# Epoch 00024: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9947 - val_loss: 0.0134 - val_accuracy: 0.9957
# Epoch 25/100
# 29/30 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9946
# Epoch 00025: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9947 - val_loss: 0.0147 - val_accuracy: 0.9957
# Epoch 26/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0223 - accuracy: 0.9945
# Epoch 00026: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9947 - val_loss: 0.0140 - val_accuracy: 0.9957
# Epoch 27/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0246 - accuracy: 0.9963
# Epoch 00027: val_loss did not improve from 0.01263
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 0.9947 - val_loss: 0.0137 - val_accuracy: 0.9957
# Epoch 28/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0133 - accuracy: 0.9948
# Epoch 00028: val_loss improved from 0.01263 to 0.01226, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0123 - val_accuracy: 0.9957
# Epoch 29/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0321 - accuracy: 0.9948
# Epoch 00029: val_loss did not improve from 0.01226
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9947 - val_loss: 0.0130 - val_accuracy: 0.9957
# Epoch 30/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0191 - accuracy: 0.9948
# Epoch 00030: val_loss did not improve from 0.01226
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 0.9947 - val_loss: 0.0151 - val_accuracy: 0.9957
# Epoch 31/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0229 - accuracy: 0.9934
# Epoch 00031: val_loss did not improve from 0.01226
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9947 - val_loss: 0.0125 - val_accuracy: 0.9957
# Epoch 32/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0102 - accuracy: 0.9963
# Epoch 00032: val_loss did not improve from 0.01226
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 0.0127 - val_accuracy: 0.9957
# Epoch 33/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0158 - accuracy: 0.9945
# Epoch 00033: val_loss improved from 0.01226 to 0.01208, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9947 - val_loss: 0.0121 - val_accuracy: 0.9957
# Epoch 34/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0281 - accuracy: 0.9926
# Epoch 00034: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 0.9947 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 35/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0254 - accuracy: 0.9908
# Epoch 00035: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9947 - val_loss: 0.0128 - val_accuracy: 0.9957
# Epoch 36/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0258 - accuracy: 0.9913
# Epoch 00036: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.0131 - val_accuracy: 0.9957
# Epoch 37/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0222 - accuracy: 0.9951
# Epoch 00037: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.0272 - val_accuracy: 0.9915
# Epoch 38/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0339 - accuracy: 0.9934
# Epoch 00038: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0268 - accuracy: 0.9947 - val_loss: 0.0156 - val_accuracy: 0.9957
# Epoch 39/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0143 - accuracy: 0.9965
# Epoch 00039: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9947 - val_loss: 0.0144 - val_accuracy: 0.9957
# Epoch 40/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0182 - accuracy: 0.9934
# Epoch 00040: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0178 - val_accuracy: 0.9915
# Epoch 41/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0132 - accuracy: 0.9961
# Epoch 00041: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0208 - val_accuracy: 0.9915
# Epoch 42/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0309 - accuracy: 0.9922
# Epoch 00042: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9947 - val_loss: 0.0184 - val_accuracy: 0.9915
# Epoch 43/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0116 - accuracy: 0.9963
# Epoch 00043: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0248 - accuracy: 0.9947 - val_loss: 0.0149 - val_accuracy: 0.9957
# Epoch 44/100
# 29/30 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9946
# Epoch 00044: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9947 - val_loss: 0.0140 - val_accuracy: 0.9957
# Epoch 45/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0197 - accuracy: 0.9963
# Epoch 00045: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9936 - val_loss: 0.0125 - val_accuracy: 0.9957
# Epoch 46/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0146 - accuracy: 0.9965
# Epoch 00046: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9936 - val_loss: 0.0138 - val_accuracy: 0.9957
# Epoch 47/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9936
# Epoch 00047: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 0.0198 - val_accuracy: 0.9915
# Epoch 48/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0194 - accuracy: 0.9963
# Epoch 00048: val_loss did not improve from 0.01208
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9947 - val_loss: 0.0125 - val_accuracy: 0.9957
# Epoch 49/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0134 - accuracy: 0.9982
# Epoch 00049: val_loss improved from 0.01208 to 0.01198, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.0120 - val_accuracy: 0.9957
# Epoch 50/100
# 29/30 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9946
# Epoch 00050: val_loss did not improve from 0.01198
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9947 - val_loss: 0.0141 - val_accuracy: 0.9957
# Epoch 51/100
# 29/30 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9946
# Epoch 00051: val_loss improved from 0.01198 to 0.01196, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.0120 - val_accuracy: 0.9957
# Epoch 52/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0283 - accuracy: 0.9926
# Epoch 00052: val_loss did not improve from 0.01196
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9947 - val_loss: 0.0138 - val_accuracy: 0.9957
# Epoch 53/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0106 - accuracy: 0.9963
# Epoch 00053: val_loss did not improve from 0.01196
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.0129 - val_accuracy: 0.9957
# Epoch 54/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0240 - accuracy: 0.9941
# Epoch 00054: val_loss did not improve from 0.01196
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.0129 - val_accuracy: 0.9957
# Epoch 55/100
# 21/30 [====================>.........] - ETA: 0s - loss: 0.0175 - accuracy: 0.9940
# Epoch 00055: val_loss did not improve from 0.01196
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 0.9936 - val_loss: 0.0127 - val_accuracy: 0.9957
# Epoch 56/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0191 - accuracy: 0.9922
# Epoch 00056: val_loss did not improve from 0.01196
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9936 - val_loss: 0.0120 - val_accuracy: 0.9957
# Epoch 57/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0157 - accuracy: 0.9953
# Epoch 00057: val_loss did not improve from 0.01196
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9925 - val_loss: 0.0125 - val_accuracy: 0.9957
# Epoch 58/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0286 - accuracy: 0.9926
# Epoch 00058: val_loss did not improve from 0.01196
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9947 - val_loss: 0.0126 - val_accuracy: 0.9957
# Epoch 59/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0131 - accuracy: 0.9969
# Epoch 00059: val_loss improved from 0.01196 to 0.01154, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0115 - val_accuracy: 0.9957
# Epoch 60/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0256 - accuracy: 0.9926
# Epoch 00060: val_loss did not improve from 0.01154
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9947 - val_loss: 0.0120 - val_accuracy: 0.9957
# Epoch 61/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0333 - accuracy: 0.9913
# Epoch 00061: val_loss did not improve from 0.01154
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 0.0135 - val_accuracy: 0.9957
# Epoch 62/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0144 - accuracy: 0.9945
# Epoch 00062: val_loss did not improve from 0.01154
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9947 - val_loss: 0.0126 - val_accuracy: 0.9957
# Epoch 63/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0122 - accuracy: 0.9965
# Epoch 00063: val_loss did not improve from 0.01154
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 0.9947 - val_loss: 0.0147 - val_accuracy: 0.9957
# Epoch 64/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0144 - accuracy: 0.9963
# Epoch 00064: val_loss did not improve from 0.01154
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9947 - val_loss: 0.0124 - val_accuracy: 0.9957
# Epoch 65/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0175 - accuracy: 0.9953
# Epoch 00065: val_loss did not improve from 0.01154
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9947 - val_loss: 0.0123 - val_accuracy: 0.9957
# Epoch 66/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0181 - accuracy: 0.9945
# Epoch 00066: val_loss did not improve from 0.01154
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0127 - val_accuracy: 0.9957
# Epoch 67/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0068 - accuracy: 0.9982
# Epoch 00067: val_loss improved from 0.01154 to 0.01137, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 0.9947 - val_loss: 0.0114 - val_accuracy: 0.9957
# Epoch 68/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0161 - accuracy: 0.9931
# Epoch 00068: val_loss did not improve from 0.01137
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9947 - val_loss: 0.0131 - val_accuracy: 0.9957
# Epoch 69/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0136 - accuracy: 0.9961
# Epoch 00069: val_loss did not improve from 0.01137
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9947 - val_loss: 0.0120 - val_accuracy: 0.9957
# Epoch 70/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0167 - accuracy: 0.9945
# Epoch 00070: val_loss did not improve from 0.01137
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9947 - val_loss: 0.0123 - val_accuracy: 0.9957
# Epoch 71/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0093 - accuracy: 0.9963
# Epoch 00071: val_loss did not improve from 0.01137
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0119 - val_accuracy: 0.9957
# Epoch 72/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0159 - accuracy: 0.9945
# Epoch 00072: val_loss improved from 0.01137 to 0.01134, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9947 - val_loss: 0.0113 - val_accuracy: 0.9957
# Epoch 73/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0104 - accuracy: 0.9965
# Epoch 00073: val_loss improved from 0.01134 to 0.01112, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0225 - accuracy: 0.9947 - val_loss: 0.0111 - val_accuracy: 0.9957
# Epoch 74/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0202 - accuracy: 0.9961
# Epoch 00074: val_loss did not improve from 0.01112
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9947 - val_loss: 0.0128 - val_accuracy: 0.9957
# Epoch 75/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0248 - accuracy: 0.9926
# Epoch 00075: val_loss did not improve from 0.01112
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0119 - val_accuracy: 0.9957
# Epoch 76/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0097 - accuracy: 0.9963
# Epoch 00076: val_loss improved from 0.01112 to 0.01111, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0111 - val_accuracy: 0.9957
# Epoch 77/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0152 - accuracy: 0.9945
# Epoch 00077: val_loss did not improve from 0.01111
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.0119 - val_accuracy: 0.9957
# Epoch 78/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0361 - accuracy: 0.9922
# Epoch 00078: val_loss did not improve from 0.01111
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9947 - val_loss: 0.0118 - val_accuracy: 0.9957
# Epoch 79/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0120 - accuracy: 0.9965
# Epoch 00079: val_loss improved from 0.01111 to 0.01109, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0111 - val_accuracy: 0.9957
# Epoch 80/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948
# Epoch 00080: val_loss did not improve from 0.01109
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.0132 - val_accuracy: 0.9957
# Epoch 81/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9947
# Epoch 00081: val_loss did not improve from 0.01109
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9947 - val_loss: 0.0121 - val_accuracy: 0.9957
# Epoch 82/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0178 - accuracy: 0.9961
# Epoch 00082: val_loss did not improve from 0.01109
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0122 - val_accuracy: 0.9957
# Epoch 83/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0196 - accuracy: 0.9922
# Epoch 00083: val_loss did not improve from 0.01109
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0113 - val_accuracy: 0.9957
# Epoch 84/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0246 - accuracy: 0.9908
# Epoch 00084: val_loss improved from 0.01109 to 0.01078, saving model to dnnModel.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.0108 - val_accuracy: 0.9957
# Epoch 85/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0270 - accuracy: 0.9967
# Epoch 00085: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0277 - accuracy: 0.9947 - val_loss: 0.0143 - val_accuracy: 0.9957
# Epoch 86/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0284 - accuracy: 0.9926
# Epoch 00086: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0233 - accuracy: 0.9947 - val_loss: 0.0135 - val_accuracy: 0.9957
# Epoch 87/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0236 - accuracy: 0.9965
# Epoch 00087: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9947 - val_loss: 0.0121 - val_accuracy: 0.9957
# Epoch 88/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9947
# Epoch 00088: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.0113 - val_accuracy: 0.9957
# Epoch 89/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0275 - accuracy: 0.9945
# Epoch 00089: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9947 - val_loss: 0.0117 - val_accuracy: 0.9957
# Epoch 90/100
# 29/30 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9946
# Epoch 00090: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9947 - val_loss: 0.0118 - val_accuracy: 0.9957
# Epoch 91/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9947
# Epoch 00091: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9947 - val_loss: 0.0110 - val_accuracy: 0.9957
# Epoch 92/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0204 - accuracy: 0.9922
# Epoch 00092: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 93/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0123 - accuracy: 0.9963
# Epoch 00093: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.0111 - val_accuracy: 0.9957
# Epoch 94/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0159 - accuracy: 0.9945
# Epoch 00094: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9947 - val_loss: 0.0115 - val_accuracy: 0.9957
# Epoch 95/100
# 18/30 [=================>............] - ETA: 0s - loss: 0.0229 - accuracy: 0.9931
# Epoch 00095: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0117 - val_accuracy: 0.9957
# Epoch 96/100
# 29/30 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9935
# Epoch 00096: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0365 - accuracy: 0.9936 - val_loss: 0.0437 - val_accuracy: 0.9915
# Epoch 97/100
# 27/30 [==========================>...] - ETA: 0s - loss: 0.0495 - accuracy: 0.9931
# Epoch 00097: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 0.9936 - val_loss: 0.0398 - val_accuracy: 0.9915
# Epoch 98/100
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0232 - accuracy: 0.9951
# Epoch 00098: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9947 - val_loss: 0.0390 - val_accuracy: 0.9915
# Epoch 99/100
# 17/30 [================>.............] - ETA: 0s - loss: 0.0207 - accuracy: 0.9963
# Epoch 00099: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0377 - val_accuracy: 0.9915
# Epoch 100/100
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0111 - accuracy: 0.9961
# Epoch 00100: val_loss did not improve from 0.01078
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 0.0403 - val_accuracy: 0.9915

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('BRNN Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
# plt.savefig('BRNN 200 Model Accuracy.png')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('BRNN Model  Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
# plt.savefig('BRNN 200 Model Loss.png')
plt.show()

# %%
predict = model.predict(data_eval, verbose=1)
# Out:
# 10/10 [==============================] - 0s 983us/step

# %%
tp = 0
tn = 0
fp = 0
fn = 0
predictn = predict.flatten().round()
predictn = predictn.tolist()
Y_testn = label_eval.tolist()
for i in range(len(Y_testn)):
  if predictn[i]==1 and Y_testn[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_testn[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_testn[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_testn[i]==0:
    fn+=1
to_heat_map =[[tn,fp],[fn,tp]]
to_heat_map = pd.DataFrame(to_heat_map, index = ["Attack","Normal"],columns = ["Attack","Normal"])
ax = sns.heatmap(to_heat_map,annot=True, fmt="d")

# %%
scores = model.evaluate(data_eval, label_eval)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9932
# accuracy: 99.32%

# %%
print(classification_report(Y_testn,predictn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       147
#            1       0.99      0.99      0.99       147
#
#     accuracy                           0.99       294
#    macro avg       0.99      0.99      0.99       294
# weighted avg       0.99      0.99      0.99       294

# %%
lr_auc = roc_auc_score(Y_testn, predictn)
print('SVM: ROC AUC=%.3f' % (lr_auc))
# Out:
# SVM: ROC AUC=0.993

# %%
time_start = time.perf_counter()
predict = model.predict(data_eval[:1], verbose=1)
print(f"Time elapse for prediction : {time.perf_counter() - time_start}")
print(predict)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# Time elapse for prediction : 0.0413103000000028
# [[1.]]

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns; sns.set()
from keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score
import joblib
import time
from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
features, labels = [], []
training_files = ["../dataset/individual/dataset_http_individual_attack_3detik_1.csv",
                  "../dataset/individual/dataset_http_individual_normal_3detik_1.csv"]

# %%
def scrape_data():
    global training_files
    global features
    global labels
    
    for fname in training_files:
        meal = open(fname, "rt")
        for line in meal:
            data_list = line.rsplit(",")
            if(len(data_list) != 11):
                print("error data")
            else:
                data_list[(len(data_list)-1)]=int(data_list[(len(data_list)-1)].replace('\n', ''))
                features.append(data_list[:(len(data_list)-1)])
                labels.append(data_list[(len(data_list)-1)])
        meal.close()
    
    data_counter = Counter(labels)
    print(data_counter)
    
    over = SMOTE()
    under = RandomUnderSampler()
    steps = [('o', over), ('u', under)]
    pipeline = Pipeline(steps=steps)
    features, labels = pipeline.fit_resample(features, labels)
    
    data_counter = Counter(labels)
    print(data_counter)
    
    scalar = StandardScaler(copy=True, with_mean=True, with_std=True)
    scalar.fit(features)
    features = scalar.transform(features)
    
    features = np.array(features).astype(np.float64)
    features = features.tolist()
    
    print(f"Size of feature dataset : {len(features)}")
    print(f"Size of feature dataset : {len(labels)}")
    print("Features first and last entries:\n\t", end = "")
    print(features[:1] + features[(len(features)-1):])
    print("Labels first and last entries:\n\t", end = "")
    print(labels[:1] + labels[(len(features)-1):])
    
    features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size = 0.20, stratify=labels, random_state = 0)
    
    return np.asarray(features_train), np.asarray(labels_train), np.asarray(features_test), np.asarray(labels_test)

# %%
def generate_model(shape):
    model = Sequential()

    model.add(Dense(256, input_dim=shape, kernel_initializer='uniform', activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    print(model.summary())

    return model

# %%
data_train, label_train, data_eval, label_eval = scrape_data()
# Out:
# Counter({0: 242, 1: 144})
# Counter({0: 242, 1: 242})
# Size of feature dataset : 484
# Size of feature dataset : 484
# Features first and last entries:
# 	[[-1.231603481136071, -0.5106052084738554, -0.26855307493873415, 0.5096758300939851, -0.3284372652980924, -0.4739024251371217, -0.046744761928801004, 2.8468214008028654, 0.0, -0.5407017481338662], [0.6188367430846399, 0.2927697149359868, -0.2243129866347959, -0.45749391997697025, 1.707055931778044, -0.4358954329889291, -0.046744761928801004, -0.41325475677122714, 0.0, 2.0980824372594835]]
# Labels first and last entries:
# 	[0, 1]
# C:\Users\H P VICTUS\anaconda3\lib\site-packages\sklearn\utils\validation.py:964: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(

# %%
model = generate_model(len(data_train[0]))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2816
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2816
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("dnnModel.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=30, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(data_train, label_train, validation_split=0.2, epochs=100, verbose = 1, callbacks=[checkpoint,early])
# Out:
# Epoch 1/100
#  1/10 [==>...........................] - ETA: 9s - loss: 0.6971 - accuracy: 0.5000
# Epoch 00001: val_loss improved from inf to 0.61132, saving model to dnnModel.h5
# 10/10 [==============================] - 1s 19ms/step - loss: 0.6730 - accuracy: 0.6311 - val_loss: 0.6113 - val_accuracy: 0.9744
# Epoch 2/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.6239 - accuracy: 0.8750
# Epoch 00002: val_loss improved from 0.61132 to 0.44869, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5850 - accuracy: 0.8738 - val_loss: 0.4487 - val_accuracy: 0.9744
# Epoch 3/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.5149 - accuracy: 0.8438
# Epoch 00003: val_loss improved from 0.44869 to 0.23036, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4335 - accuracy: 0.9126 - val_loss: 0.2304 - val_accuracy: 0.9744
# Epoch 4/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.3525 - accuracy: 0.9062
# Epoch 00004: val_loss improved from 0.23036 to 0.10137, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2341 - accuracy: 0.9482 - val_loss: 0.1014 - val_accuracy: 0.9744
# Epoch 5/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1495 - accuracy: 0.9688
# Epoch 00005: val_loss improved from 0.10137 to 0.07548, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1313 - accuracy: 0.9806 - val_loss: 0.0755 - val_accuracy: 0.9872
# Epoch 6/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.3345 - accuracy: 0.9062
# Epoch 00006: val_loss improved from 0.07548 to 0.07356, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1104 - accuracy: 0.9806 - val_loss: 0.0736 - val_accuracy: 0.9872
# Epoch 7/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1046 - accuracy: 0.9688
# Epoch 00007: val_loss improved from 0.07356 to 0.07231, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0666 - accuracy: 0.9903 - val_loss: 0.0723 - val_accuracy: 0.9872
# Epoch 8/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0160 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.07231
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0366 - accuracy: 0.9935 - val_loss: 0.0768 - val_accuracy: 0.9872
# Epoch 9/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.07231
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0405 - accuracy: 0.9935 - val_loss: 0.0773 - val_accuracy: 0.9872
# Epoch 10/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.07231
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0500 - accuracy: 0.9935 - val_loss: 0.0725 - val_accuracy: 0.9872
# Epoch 11/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00011: val_loss did not improve from 0.07231
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 0.9903 - val_loss: 0.0723 - val_accuracy: 0.9872
# Epoch 12/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 00012: val_loss improved from 0.07231 to 0.06710, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0487 - accuracy: 0.9935 - val_loss: 0.0671 - val_accuracy: 0.9872
# Epoch 13/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0542 - accuracy: 0.9688
# Epoch 00013: val_loss improved from 0.06710 to 0.06572, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0258 - accuracy: 0.9903 - val_loss: 0.0657 - val_accuracy: 0.9872
# Epoch 14/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 00014: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0281 - accuracy: 0.9968 - val_loss: 0.0703 - val_accuracy: 0.9872
# Epoch 15/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00015: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9935 - val_loss: 0.0767 - val_accuracy: 0.9872
# Epoch 16/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0187 - accuracy: 1.0000
# Epoch 00016: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9968 - val_loss: 0.0712 - val_accuracy: 0.9872
# Epoch 17/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00017: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 0.9968 - val_loss: 0.0715 - val_accuracy: 0.9872
# Epoch 18/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00018: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9935 - val_loss: 0.0737 - val_accuracy: 0.9872
# Epoch 19/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 00019: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 0.9968 - val_loss: 0.0684 - val_accuracy: 0.9872
# Epoch 20/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 00020: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0363 - accuracy: 0.9968 - val_loss: 0.0719 - val_accuracy: 0.9872
# Epoch 21/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00021: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 0.0772 - val_accuracy: 0.9872
# Epoch 22/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 00022: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9968 - val_loss: 0.0780 - val_accuracy: 0.9872
# Epoch 23/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 00023: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0262 - accuracy: 0.9968 - val_loss: 0.0763 - val_accuracy: 0.9872
# Epoch 24/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00024: val_loss did not improve from 0.06572
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0455 - accuracy: 0.9968 - val_loss: 0.0742 - val_accuracy: 0.9872
# Epoch 25/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 00025: val_loss improved from 0.06572 to 0.06275, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0280 - accuracy: 0.9968 - val_loss: 0.0627 - val_accuracy: 0.9872
# Epoch 26/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00026: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 0.9968 - val_loss: 0.0662 - val_accuracy: 0.9872
# Epoch 27/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00027: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9968 - val_loss: 0.0662 - val_accuracy: 0.9872
# Epoch 28/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 00028: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 0.9968 - val_loss: 0.0746 - val_accuracy: 0.9872
# Epoch 29/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00029: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0455 - accuracy: 0.9968 - val_loss: 0.0695 - val_accuracy: 0.9872
# Epoch 30/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 00030: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 0.9968 - val_loss: 0.0722 - val_accuracy: 0.9872
# Epoch 31/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 00031: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9968 - val_loss: 0.0758 - val_accuracy: 0.9872
# Epoch 32/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00032: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0262 - accuracy: 0.9968 - val_loss: 0.0794 - val_accuracy: 0.9872
# Epoch 33/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00033: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9968 - val_loss: 0.0676 - val_accuracy: 0.9872
# Epoch 34/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00034: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9968 - val_loss: 0.0652 - val_accuracy: 0.9872
# Epoch 35/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0134 - accuracy: 1.0000
# Epoch 00035: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 0.9968 - val_loss: 0.0732 - val_accuracy: 0.9872
# Epoch 36/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00036: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0513 - accuracy: 0.9968 - val_loss: 0.0795 - val_accuracy: 0.9872
# Epoch 37/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1788 - accuracy: 0.9688
# Epoch 00037: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9968 - val_loss: 0.0647 - val_accuracy: 0.9872
# Epoch 38/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00038: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.0677 - val_accuracy: 0.9872
# Epoch 39/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00039: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 0.9968 - val_loss: 0.0699 - val_accuracy: 0.9872
# Epoch 40/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 00040: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9968 - val_loss: 0.0740 - val_accuracy: 0.9872
# Epoch 41/100
#  1/10 [==>...........................] - ETA: 0s - loss: 6.9797e-04 - accuracy: 1.0000
# Epoch 00041: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 0.9968 - val_loss: 0.0759 - val_accuracy: 0.9872
# Epoch 42/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00042: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9968 - val_loss: 0.0736 - val_accuracy: 0.9872
# Epoch 43/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00043: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 0.9968 - val_loss: 0.0718 - val_accuracy: 0.9872
# Epoch 44/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 00044: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0208 - accuracy: 0.9968 - val_loss: 0.0693 - val_accuracy: 0.9872
# Epoch 45/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1362 - accuracy: 0.9688
# Epoch 00045: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 0.9968 - val_loss: 0.0651 - val_accuracy: 0.9872
# Epoch 46/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.2358 - accuracy: 0.9688
# Epoch 00046: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0329 - accuracy: 0.9968 - val_loss: 0.0684 - val_accuracy: 0.9872
# Epoch 47/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 00047: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9968 - val_loss: 0.0745 - val_accuracy: 0.9872
# Epoch 48/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0229 - accuracy: 0.9968 - val_loss: 0.0740 - val_accuracy: 0.9872
# Epoch 49/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00049: val_loss did not improve from 0.06275
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9968 - val_loss: 0.0727 - val_accuracy: 0.9872
# Epoch 50/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 00050: val_loss improved from 0.06275 to 0.06166, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0221 - accuracy: 0.9968 - val_loss: 0.0617 - val_accuracy: 0.9872
# Epoch 51/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 0.9935 - val_loss: 0.0626 - val_accuracy: 0.9872
# Epoch 52/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1563 - accuracy: 0.9688
# Epoch 00052: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0253 - accuracy: 0.9968 - val_loss: 0.0635 - val_accuracy: 0.9872
# Epoch 53/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00053: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9968 - val_loss: 0.0757 - val_accuracy: 0.9872
# Epoch 54/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 00054: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9968 - val_loss: 0.0742 - val_accuracy: 0.9872
# Epoch 55/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00055: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.9968 - val_loss: 0.0711 - val_accuracy: 0.9872
# Epoch 56/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00056: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 0.9968 - val_loss: 0.0666 - val_accuracy: 0.9872
# Epoch 57/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00057: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9968 - val_loss: 0.0673 - val_accuracy: 0.9872
# Epoch 58/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00058: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9968 - val_loss: 0.0669 - val_accuracy: 0.9872
# Epoch 59/100
#  1/10 [==>...........................] - ETA: 0s - loss: 4.9306e-04 - accuracy: 1.0000
# Epoch 00059: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 0.0705 - val_accuracy: 0.9872
# Epoch 60/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00060: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9968 - val_loss: 0.0753 - val_accuracy: 0.9872
# Epoch 61/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 00061: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9968 - val_loss: 0.0662 - val_accuracy: 0.9872
# Epoch 62/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9968 - val_loss: 0.0638 - val_accuracy: 0.9872
# Epoch 63/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 00063: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9968 - val_loss: 0.0652 - val_accuracy: 0.9872
# Epoch 64/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1841 - accuracy: 0.9688
# Epoch 00064: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9935 - val_loss: 0.0697 - val_accuracy: 0.9872
# Epoch 65/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00065: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9935 - val_loss: 0.0713 - val_accuracy: 0.9872
# Epoch 66/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0297 - accuracy: 0.9968 - val_loss: 0.0637 - val_accuracy: 0.9872
# Epoch 67/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00067: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.9968 - val_loss: 0.0685 - val_accuracy: 0.9872
# Epoch 68/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9968 - val_loss: 0.0748 - val_accuracy: 0.9872
# Epoch 69/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 00069: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0301 - accuracy: 0.9968 - val_loss: 0.0721 - val_accuracy: 0.9872
# Epoch 70/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 00070: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9968 - val_loss: 0.0731 - val_accuracy: 0.9872
# Epoch 71/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00071: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0305 - accuracy: 0.9968 - val_loss: 0.0708 - val_accuracy: 0.9872
# Epoch 72/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 00072: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9968 - val_loss: 0.0741 - val_accuracy: 0.9872
# Epoch 73/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00073: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9968 - val_loss: 0.0655 - val_accuracy: 0.9872
# Epoch 74/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00074: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9968 - val_loss: 0.0634 - val_accuracy: 0.9872
# Epoch 75/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0263 - accuracy: 0.9968 - val_loss: 0.0749 - val_accuracy: 0.9872
# Epoch 76/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00076: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0241 - accuracy: 0.9968 - val_loss: 0.0649 - val_accuracy: 0.9872
# Epoch 77/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00077: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9968 - val_loss: 0.0646 - val_accuracy: 0.9872
# Epoch 78/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1984 - accuracy: 0.9688
# Epoch 00078: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 0.9968 - val_loss: 0.0624 - val_accuracy: 0.9872
# Epoch 79/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 0.06166
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9968 - val_loss: 0.0737 - val_accuracy: 0.9872
# Epoch 80/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1199 - accuracy: 0.9688
# Epoch 00080: val_loss improved from 0.06166 to 0.06129, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0211 - accuracy: 0.9935 - val_loss: 0.0613 - val_accuracy: 0.9872
# Epoch 81/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1406 - accuracy: 0.9688
# Epoch 00081: val_loss did not improve from 0.06129
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9968 - val_loss: 0.0626 - val_accuracy: 0.9872
# Epoch 82/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 00082: val_loss did not improve from 0.06129
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.9968 - val_loss: 0.0787 - val_accuracy: 0.9872
# Epoch 83/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00083: val_loss did not improve from 0.06129
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9968 - val_loss: 0.0842 - val_accuracy: 0.9872
# Epoch 84/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00084: val_loss did not improve from 0.06129
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 0.9968 - val_loss: 0.0767 - val_accuracy: 0.9872
# Epoch 85/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00085: val_loss did not improve from 0.06129
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0204 - accuracy: 0.9968 - val_loss: 0.0717 - val_accuracy: 0.9872
# Epoch 86/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00086: val_loss did not improve from 0.06129
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0509 - accuracy: 0.9968 - val_loss: 0.0738 - val_accuracy: 0.9872
# Epoch 87/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00087: val_loss improved from 0.06129 to 0.05214, saving model to dnnModel.h5
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0274 - accuracy: 0.9968 - val_loss: 0.0521 - val_accuracy: 0.9872
# Epoch 88/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00088: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0206 - accuracy: 0.9968 - val_loss: 0.0584 - val_accuracy: 0.9872
# Epoch 89/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 00089: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9968 - val_loss: 0.0743 - val_accuracy: 0.9872
# Epoch 90/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00090: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0135 - accuracy: 0.9968 - val_loss: 0.0848 - val_accuracy: 0.9872
# Epoch 91/100
#  1/10 [==>...........................] - ETA: 0s - loss: 5.3617e-04 - accuracy: 1.0000
# Epoch 00091: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0325 - accuracy: 0.9968 - val_loss: 0.0822 - val_accuracy: 0.9872
# Epoch 92/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1790 - accuracy: 0.9688
# Epoch 00092: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0211 - accuracy: 0.9968 - val_loss: 0.0636 - val_accuracy: 0.9872
# Epoch 93/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 00093: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0279 - accuracy: 0.9968 - val_loss: 0.0651 - val_accuracy: 0.9872
# Epoch 94/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 00094: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 0.9968 - val_loss: 0.0708 - val_accuracy: 0.9872
# Epoch 95/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 00095: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0265 - accuracy: 0.9968 - val_loss: 0.0700 - val_accuracy: 0.9872
# Epoch 96/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0308 - accuracy: 0.9968 - val_loss: 0.0600 - val_accuracy: 0.9872
# Epoch 97/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 00097: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0205 - accuracy: 0.9968 - val_loss: 0.0632 - val_accuracy: 0.9872
# Epoch 98/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00098: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0244 - accuracy: 0.9968 - val_loss: 0.0647 - val_accuracy: 0.9872
# Epoch 99/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00099: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0285 - accuracy: 0.9968 - val_loss: 0.0634 - val_accuracy: 0.9872
# Epoch 100/100
#  1/10 [==>...........................] - ETA: 0s - loss: 6.2024e-04 - accuracy: 1.0000
# Epoch 00100: val_loss did not improve from 0.05214
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0305 - accuracy: 0.9968 - val_loss: 0.0605 - val_accuracy: 0.9872

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('BRNN Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
# plt.savefig('BRNN 200 Model Accuracy.png')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('BRNN Model  Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
# plt.savefig('BRNN 200 Model Loss.png')
plt.show()

# %%
predict = model.predict(data_eval, verbose=1)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
tp = 0
tn = 0
fp = 0
fn = 0
predictn = predict.flatten().round()
predictn = predictn.tolist()
Y_testn = label_eval.tolist()
for i in range(len(Y_testn)):
  if predictn[i]==1 and Y_testn[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_testn[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_testn[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_testn[i]==0:
    fn+=1
to_heat_map =[[tn,fp],[fn,tp]]
to_heat_map = pd.DataFrame(to_heat_map, index = ["Attack","Normal"],columns = ["Attack","Normal"])
ax = sns.heatmap(to_heat_map,annot=True, fmt="d")

# %%
scores = model.evaluate(data_eval, label_eval)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0479 - accuracy: 0.9794
# accuracy: 97.94%

# %%
print(classification_report(Y_testn,predictn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        49
#            1       0.98      0.98      0.98        48
#
#     accuracy                           0.98        97
#    macro avg       0.98      0.98      0.98        97
# weighted avg       0.98      0.98      0.98        97

# %%
lr_auc = roc_auc_score(Y_testn, predictn)
print('SVM: ROC AUC=%.3f' % (lr_auc))
# Out:
# SVM: ROC AUC=0.979

# %%
time_start = time.perf_counter()
predict = model.predict(data_eval[:1], verbose=1)
print(f"Time elapse for prediction : {time.perf_counter() - time_start}")
print(predict)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Time elapse for prediction : 0.03440709999999925
# [[1.1111134e-05]]
